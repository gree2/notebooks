# %%
import numpy as np

from bokeh.io import push_notebook
from bokeh.client import push_session
from bokeh.models import ColumnDataSource, DataRange1d, Plot, Circle, Button, TapTool
from bokeh.plotting import curdoc, output_notebook, show, vplot, hplot

# %%
document = curdoc()
session = push_session(document)
output_notebook()
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>

# %%
N = 9

x = np.linspace(-2, 2, N)
y = x**2
source1 = ColumnDataSource(dict(x=x, y=y, size=[20]*N))
xdr1 = DataRange1d()
ydr1 = DataRange1d()
plot1 = Plot(title="Plot1", x_range=xdr1, y_range=ydr1, plot_width=400, plot_height=400)
plot1.tools.append(TapTool(plot=plot1))
plot1.add_glyph(source1, Circle(x="x", y="y", size="size", fill_color="red"))

source2 = ColumnDataSource(dict(x=x, y=y, color=["blue"]*N))
xdr2 = DataRange1d()
ydr2 = DataRange1d()
plot2 = Plot(title="Plot2", x_range=xdr2, y_range=ydr2, plot_width=400, plot_height=400)
plot2.tools.append(TapTool(plot=plot2))
plot2.add_glyph(source2, Circle(x="x", y="y", size=20, fill_color="color"))

# %%
def on_selection_change1(obj, attr, inds):
    color = ["blue"]*N
    if inds['1d']['indices']:
        [index] = inds['1d']['indices']
        color[index] = "red"
    source2.data["color"] = color
    push_notebook()


source1.on_change('selected', on_selection_change1)


def on_selection_change2(obj, attr, inds):
    inds = inds['1d']['indices']
    if inds:
        [index] = inds
        size = [10]*N
        size[index] = 40
    else:
        size = [20]*N
    source1.data["size"] = size
    push_notebook()


source2.on_change('selected', on_selection_change2)
reset = Button(label="Reset")


def on_reset_click():
    source1.selected = {
        '0d': {'flag': False, 'indices': []},
        '1d': {'indices': []},
        '2d': {'indices': []}
    }
    source2.selected = {
        '0d': {'flag': False, 'indices': []},
        '1d': {'indices': []},
        '2d': {'indices': []}
    }
    push_notebook()

reset.on_click(on_reset_click)
v = vplot(reset)
p = hplot(v, plot1, plot2)
show(p);
# Out:
#     <div class="plotdiv" id="97f94f67-15ee-42c9-9389-cf16379dd42c"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("97f94f67-15ee-42c9-9389-cf16379dd42c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '97f94f67-15ee-42c9-9389-cf16379dd42c' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"84e967a5-6e09-4ccb-afe2-e8e7a3607d06": {"version": "0.11.0", "roots": {"root_ids": ["cdd4ebc7-9a12-4c49-aeb3-9a89e5c0b24a"], "references": [{"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "3bd6ac5a-7139-4465-a9e9-1cc291c1a1af"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Circle", "id": "147d760d-57ce-4d0c-a6e2-6437f9ad0c56"}}, "type": "GlyphRenderer", "id": "9f7eb764-e2f4-4cb0-8c6e-9885ca70d77a"}, {"attributes": {"callback": null, "plot": {"type": "Plot", "id": "c6e4736e-e049-4c17-9094-a319c6c405f5"}}, "type": "TapTool", "id": "3682025c-297d-4700-b96d-09778cbc91ed"}, {"attributes": {}, "type": "ToolEvents", "id": "72a916dd-aaf5-4ab8-a03f-bc6f4fd5825e"}, {"attributes": {"callback": null, "column_names": ["color", "y", "x"], "data": {"color": ["blue", "blue", "blue", "blue", "blue", "blue", "blue", "blue", "blue"], "x": [-2.0, -1.5, -1.0, -0.5, 0.0, 0.5, 1.0, 1.5, 2.0], "y": [4.0, 2.25, 1.0, 0.25, 0.0, 0.25, 1.0, 2.25, 4.0]}}, "type": "ColumnDataSource", "id": "791c6d88-0aea-4843-b1c8-b4f952748ae0"}, {"attributes": {"x_range": {"type": "DataRange1d", "id": "bb35bf57-3a29-4163-9022-92d0009d435d"}, "title": "Plot1", "y_range": {"type": "DataRange1d", "id": "87c8cdf9-e449-4d70-bebe-6066e5e0ed05"}, "renderers": [{"type": "GlyphRenderer", "id": "9f7eb764-e2f4-4cb0-8c6e-9885ca70d77a"}], "plot_width": 400, "plot_height": 400, "tool_events": {"type": "ToolEvents", "id": "450741c8-225a-4af0-a66c-07aebb063506"}, "tools": [{"type": "TapTool", "id": "b2238545-def1-41bd-90eb-98e07974382d"}]}, "type": "Plot", "id": "efba33b0-caea-49b7-b5d9-d398365ddbf4"}, {"attributes": {}, "type": "ToolEvents", "id": "450741c8-225a-4af0-a66c-07aebb063506"}, {"attributes": {"children": [{"type": "Button", "id": "b3d755f1-a32b-426c-b73d-2417f3d66712"}]}, "type": "VBox", "id": "e231b222-8e48-4a44-a197-30626039c59f"}, {"attributes": {"y": {"field": "y"}, "x": {"field": "x"}, "fill_color": {"value": "red"}, "size": {"units": "screen", "field": "size"}}, "type": "Circle", "id": "147d760d-57ce-4d0c-a6e2-6437f9ad0c56"}, {"attributes": {"children": [{"type": "VBox", "id": "e231b222-8e48-4a44-a197-30626039c59f"}, {"type": "Plot", "id": "efba33b0-caea-49b7-b5d9-d398365ddbf4"}, {"type": "Plot", "id": "c6e4736e-e049-4c17-9094-a319c6c405f5"}]}, "type": "HBox", "id": "cdd4ebc7-9a12-4c49-aeb3-9a89e5c0b24a"}, {"attributes": {"callback": null}, "type": "DataRange1d", "id": "e7f01e24-ca30-4d38-ae9f-7767c6ad4d43"}, {"attributes": {"x_range": {"type": "DataRange1d", "id": "e7f01e24-ca30-4d38-ae9f-7767c6ad4d43"}, "title": "Plot2", "y_range": {"type": "DataRange1d", "id": "a61460dc-55ff-4a7b-b3bf-98f700311888"}, "renderers": [{"type": "GlyphRenderer", "id": "cdbe00f7-d9f8-471f-b556-8cf4f5f7cf8e"}], "plot_width": 400, "plot_height": 400, "tool_events": {"type": "ToolEvents", "id": "72a916dd-aaf5-4ab8-a03f-bc6f4fd5825e"}, "tools": [{"type": "TapTool", "id": "3682025c-297d-4700-b96d-09778cbc91ed"}]}, "type": "Plot", "id": "c6e4736e-e049-4c17-9094-a319c6c405f5"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "791c6d88-0aea-4843-b1c8-b4f952748ae0"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Circle", "id": "f55fe2f2-ddf2-472c-8cbd-1c1253aa7283"}}, "type": "GlyphRenderer", "id": "cdbe00f7-d9f8-471f-b556-8cf4f5f7cf8e"}, {"attributes": {"y": {"field": "y"}, "x": {"field": "x"}, "fill_color": {"field": "color"}, "size": {"units": "screen", "value": 20}}, "type": "Circle", "id": "f55fe2f2-ddf2-472c-8cbd-1c1253aa7283"}, {"attributes": {"callback": null}, "type": "DataRange1d", "id": "87c8cdf9-e449-4d70-bebe-6066e5e0ed05"}, {"attributes": {"callback": null, "label": "Reset", "icon": null}, "type": "Button", "id": "b3d755f1-a32b-426c-b73d-2417f3d66712"}, {"attributes": {"callback": null}, "type": "DataRange1d", "id": "a61460dc-55ff-4a7b-b3bf-98f700311888"}, {"attributes": {"callback": null}, "type": "DataRange1d", "id": "bb35bf5 ...
#             var render_items = [{"notebook_comms_target": "e858b158-dbeb-4de5-9abc-8750c82fc18d", "docid": "84e967a5-6e09-4ccb-afe2-e8e7a3607d06", "elementid": "97f94f67-15ee-42c9-9389-cf16379dd42c", "modelid": "cdd4ebc7-9a12-4c49-aeb3-9a89e5c0b24a"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#         });
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#       for (var i = 0; i < inline_js.length; i++) {
#         inline_js[i](window.Bokeh);
#       }
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>

# %%
session.show()
session.loop_until_closed()
